# %%
## Hello World example

print("Hello World")
# Out:
# Hello World

# %%
import sys
import subprocess

script_filename = "hello_world.py"

with open(script_filename, "w", encoding="utf-8") as file_handle:
    file_handle.write('print("Hello World")\n')

subprocess.run([sys.executable, script_filename], check=True)
# Out:
# CompletedProcess(args=['C:\\Users\\Nass3\\Documents\\GitHub\\ML\\.venv\\Scripts\\python.exe', 'hello_world.py'], returncode=0)
